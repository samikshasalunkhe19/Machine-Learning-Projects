# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshasalunkhe19/Machine-Learning-Projects/blob/main/movie_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas for data handling
import pandas as pd
#import numpy for numerical operation
import numpy as np

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tmdb/tmdb-movie-metadata")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'tmdb-movie-metadata' dataset.
# Path to dataset files: /kaggle/input/tmdb-movie-metadata

# %%
import os
os.listdir(path)
# Out:
# ['tmdb_5000_movies.csv', 'tmdb_5000_credits.csv']

# %%
movies=pd.read_csv(path+"/tmdb_5000_movies.csv")
movies.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
#display last 5 rows
movies.tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
movies.shape
# Out:
# (1493, 2)

# %%
movies.columns
# Out:
# Index(['title', 'overview'], dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1493 entries, 0 to 1492
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1493 non-null   object
#  1   overview  1493 non-null   object
# dtypes: object(2)
# memory usage: 23.5+ KB

# %%
#check for null values
movies.isnull().sum()
# Out:
# title       0
# overview    0
# dtype: int64

# %%
#count number of unique movie titles
movies['title'].nunique()
# Out:
# 1493

# %%
#check if there are duplicate rows
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
#display 5 random movies
movies.sample(5)
# Out:
#                          title  \
# 434   Resident Evil: Afterlife
# 865                   The Debt
# 672            This Is the End
# 1108                Sugar Hill
# 1276                     Scoop
#
#                                                overview
# 434   In a world ravaged by a virus infection, turni...
# 865   Rachel Singer is a former Mossad agent who tri...
# 672   While attending a party at James Franco's hous...
# 1108  Sugar Hill is a 1994 American crime-drama/neo-...
# 1276  An American journalism student in London scoop...

# %%
#check datatypes
movies.dtypes
# Out:
# title       object
# overview    object
# dtype: object

# %%
#analyze length of movies
movies['overview'].str.len().describe()
# Out:
# count    1493.000000
# mean      308.111855
# std       157.478639
# min        58.000000
# 25%       187.000000
# 50%       281.000000
# 75%       395.000000
# max      1000.000000
# Name: overview, dtype: float64

# %%
#view complete info of first movie
movies.iloc[0]
# Out:
# title                                                  Avatar
# overview    In the 22nd century, a paraplegic Marine is di...
# Name: 0, dtype: object

# %% [markdown]
# Data cleaning phase

# %%
movies=movies[['title','overview']]
movies.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
movies.dropna(inplace=True)
# Out:
# /tmp/ipykernel_435/3786870272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies.reset_index(drop=True,inplace=True)

# %%
movies.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %% [markdown]
# Data enginering phase

# %%
movies['content']=movies['overview']
# Out:
# /tmp/ipykernel_435/665781940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['content']=movies['overview']

# %%
movies['content']=movies['content'].str.lower()
# Out:
# /tmp/ipykernel_435/3919324589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['content']=movies['content'].str.lower()

# %%
movies[['title','content']].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                              content
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer=TfidfVectorizer(stop_words='english')

vectors=vectorizer.fit_transform(movies['content'])

# %%
vectors.shape
# Out:
# (1493, 11160)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
def recommend(movie_name):
  idx=movies[movies['title']==movie_name].index[0]
  #get index of the selected movie
  scores=list(enumerate(similarity[idx]))
  scores=sorted(scores,key=lambda x:x[1],reverse=True)
  return [movies.iloc[i[0]].title for i in scores[1:6]]

# %%
recommend("Inception")
# Out:
# ['Mission: Impossible - Rogue Nation',
#  'Cypher',
#  'Central Intelligence',
#  'Peaceful Warrior',
#  'Duplicity']
